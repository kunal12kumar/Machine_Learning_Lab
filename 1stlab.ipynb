# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# To practice for lap

# %%
#creating two list to plot on graph
# for plot size on x axis 1 unit is equal to 1000 dollar
plot_size_x=[1.0, 2.0] 
# for plot pric of land on y axis  1 unit is equal to 1000 dollar
plot_size_y=[200, 500]

plt.plot(plot_size_x, plot_size_y,color="g")
plt.show()

# %%
# Now using array

# %%
x_size=np.array(plot_size_x)
y_price=np.array(plot_size_y)
plt.plot(x_size,y_price,color="y")
plt.show()

# %%
print(f"x_size ={x_size}")
# Out:
# x_size =[1. 2.]

# %% [markdown]
# from here we are again starting the

# %%
# creating array for the plot size and price

# %%
size=np.array([1 ,2 ])
price=np.array([200, 500])

# %%
w=100
b=40
print(f" w={w} b={b}")
# Out:
#  w=100 b=40

# %%
# creating a function to calculate the price

# %%
def calculateprice(x,w,b):
    # to how many times the for loop will run
    t=size.shape[0]
    print(t)
    output_array=np.zeros(t)
    for i in range(t):
        astimated_price=(w*size[i] + b)
        print(astimated_price)
        output_array[i]=astimated_price
    return output_array

# %%
predicted_price=calculateprice(size,w,b)
# Out:
# 2
# 140
# 240

# %%
# now plotting the scatter plot for testing

# %%
size=np.array([1 ,2 ])
price=np.array([200, 500])
plt.plot(size,price,color="g")

w=100
b=40
print(f" w={w} b={b}")



# creating a function to calculate the price

def calculateprice(x,w,b):
    # to how many times the for loop will run
    t=size.shape[0]
    print(t)
    output_array=np.zeros(t)
    for i in range(t):
        astimated_price=(w*size[i] + b)
        print(astimated_price)
        output_array[i]=astimated_price
    return output_array

predicted_price=calculateprice(size,w,b)
print(predicted_price)

# now plotting with the astimated value

plt.plot(size,price,color="r")
plt.show()
plt.scatter(size,price)
plt.show()
# now plotting with the astimated value 

plt.scatter(size, predicted_price)
plt.show()
plt.plot(size,predicted_price, color="b")
plt.show()
# Out:
#  w=100 b=40
# 2
# 140
# 240
# [140. 240.]
